# %% [markdown]
# # Create SRA submission sheet
# This Python Jupyter notebook creates a BioSample submission sheet for the Sequence Read Archive:
#
# First, import Python modules:

# %%
import datetime
import glob
import itertools
import os

import natsort

import pandas as pd

import yaml

# %% [markdown]
# Display full columns of data frames:

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Read the configuration for the uploads:

# %%
with open('upload_config.yaml') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# Read the Illumina runs to submit:

# %%
print(f"Reading Illumina runs from {config['barcode_runs']}")

illumina_runs = pd.read_csv(config['barcode_runs'])

print('Here are the first few entries in the Illumina runs:')
illumina_runs.head()
# Out:
# Reading Illumina runs from barcode_runs_to_upload.csv
# Here are the first few entries in the Illumina runs:
#      date experiment       target library    antibody  concentration sort_bin  \
# 0  220422    exptREF   Wuhan_Hu_1   lib12        none              0      ref
# 1  220422    exptREF   Wuhan_Hu_1   lib13        none              0      ref
# 2  220422      expt1   Wuhan_Hu_1   lib12  LY-CoV1404            154    abneg
# 3  220422      expt1   Wuhan_Hu_1   lib13  LY-CoV1404            154    abneg
# 4  220422    exptREF  Omicron_BA1   lib22        none              0      ref
#
#    selection                      sample experiment_type  number_cells  \
# 0  reference          exptREF-none-0-ref    ab_selection           NaN
# 1  reference          exptREF-none-0-ref    ab_selection           NaN
# 2     escape  expt1-LY-CoV1404-154-abneg             NaN      276693.0
# 3     escape  expt1-LY-CoV1404-154-abneg             NaN      294136.0
# 4  reference          exptREF-none-0-ref    ab_selection           NaN
#
#    frac_escape  \
# 0          NaN
# 1          NaN
# 2        0.075
# 3        0.075
# 4          NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     R1
# 0  /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib1_ref1_S33_R1_001.fastq.gz; /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib1_ref2_S34_R1_001.fastq.gz; /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib1_ref13_S35_R1_001.fastq.gz; /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib1_ref4_S36_R1_001.fastq.gz
# 1   /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib2_ref1_S37_R1_001.fastq.gz; /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib2_ref2_S38_R1_001.fastq.gz; /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib2_ref3_S39_R1_001.fastq.gz; /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib2_ref4_S40_R1_001.fastq.gz
# 2                                                                                                                                                                                                                                                                                                                                                                      /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/expt1_lib1_S1_R1_001.fastq.gz
# 3                                                                                                                                                                                                                                                                                                                                                                      /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/expt1_lib2_S2_R1_001.fastq.gz
# 4  /shared/ngs/illumina/tstarr/220504_VH00319_203_AAAYKKMM5/Unaligned/Project_tstarr/BA1_lib1_ref1_S54_R1_001.fastq.gz; /shared/ngs/illumina/tstarr/220504_VH00319_203_AAAYKKMM5/Unaligned/Project_tstarr/BA1_lib1_ref2_S55_R1_001.fastq.gz; /shared/ngs/illumina/tstarr/220504_VH00319_203_AAAYKKMM5/Unaligned/Project_tstarr/BA1_lib1_ref13_S56_R1_001.fastq.gz; /shared/ngs/illumina/tstarr/220504_VH00319_203_AAAYKKMM5/Unaligned/Project_tstarr/BA1_lib1_ref4_S57_R1_001.fastq.gz

# %% [markdown]
# Next make submission entries for the barcode runs, initially in "tidy" format with one FASTQ file per row:

# %%
submissions_tidy = (
    illumina_runs
    .assign(
        biosample_accession=lambda x: config['biosample_accession'],
        library_ID=lambda x: x['library'] + '_' + x['sample'],
        title=lambda x: 'Illumina barcode sequencing from LY-CoV1404 mutational antigenic profiling of the SARS-CoV-2 RBD ' + x['target'],
        library_strategy='AMPLICON',
        library_source='SYNTHETIC',
        library_selection='PCR',
        library_layout='single',
        platform='ILLUMINA',
        instrument_model='NextSeq 2000',
        design_description='PCR of barcodes from RBD variants',
        filetype='fastq',
        filename_fullpath=lambda x: x['R1'].str.split(';')
                                    .map(lambda flist: list(itertools.chain.from_iterable(glob.glob(f.strip()) for f in flist))),       
        )
    .explode('filename_fullpath')
    .assign(filename_fullpath=lambda x: x['filename_fullpath'].str.strip(),
            filename=lambda x: x['filename_fullpath'].map(os.path.basename))
    .drop(columns=illumina_runs.columns)
    .reset_index(drop=True)
    )

assert submissions_tidy['filename_fullpath'].map(os.path.isfile).all()

print('Here are the first few submission entries in tidy format:')
submissions_tidy.head()
# Out:
# Here are the first few submission entries in tidy format:
#   biosample_accession                library_ID  \
# 0        SAMN30603977  lib12_exptREF-none-0-ref
# 1        SAMN30603977  lib12_exptREF-none-0-ref
# 2        SAMN30603977  lib12_exptREF-none-0-ref
# 3        SAMN30603977  lib12_exptREF-none-0-ref
# 4        SAMN30603977  lib13_exptREF-none-0-ref
#
#                                                                                                          title  \
# 0  Illumina barcode sequencing from LY-CoV1404 mutational antigenic profiling of the SARS-CoV-2 RBD Wuhan_Hu_1
# 1  Illumina barcode sequencing from LY-CoV1404 mutational antigenic profiling of the SARS-CoV-2 RBD Wuhan_Hu_1
# 2  Illumina barcode sequencing from LY-CoV1404 mutational antigenic profiling of the SARS-CoV-2 RBD Wuhan_Hu_1
# 3  Illumina barcode sequencing from LY-CoV1404 mutational antigenic profiling of the SARS-CoV-2 RBD Wuhan_Hu_1
# 4  Illumina barcode sequencing from LY-CoV1404 mutational antigenic profiling of the SARS-CoV-2 RBD Wuhan_Hu_1
#
#   library_strategy library_source library_selection library_layout  platform  \
# 0         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 1         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 2         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 3         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 4         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
#
#   instrument_model                 design_description filetype  \
# 0     NextSeq 2000  PCR of barcodes from RBD variants    fastq
# 1     NextSeq 2000  PCR of barcodes from RBD variants    fastq
# 2     NextSeq 2000  PCR of barcodes from RBD variants    fastq
# 3     NextSeq 2000  PCR of barcodes from RBD variants    fastq
# 4     NextSeq 2000  PCR of barcodes from RBD variants    fastq
#
#                                                                                                       filename_fullpath  \
# 0   /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib1_ref1_S33_R1_001.fastq.gz
# 1   /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib1_ref2_S34_R1_001.fastq.gz
# 2  /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib1_ref13_S35_R1_001.fastq.gz
# 3   /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib1_ref4_S36_R1_001.fastq.gz
# 4   /shared/ngs/illumina/tstarr/220824_VH00699_190_AAC5MW3M5/Unaligned/Project_tstarr/WH1_lib2_ref1_S37_R1_001.fastq.gz
#
#                              filename
# 0   WH1_lib1_ref1_S33_R1_001.fastq.gz
# 1   WH1_lib1_ref2_S34_R1_001.fastq.gz
# 2  WH1_lib1_ref13_S35_R1_001.fastq.gz
# 3   WH1_lib1_ref4_S36_R1_001.fastq.gz
# 4   WH1_lib2_ref1_S37_R1_001.fastq.gz

# %% [markdown]
# For the actual submission, we need a "wide" data frame that for each unique `sample_name` / `library_ID` gives all of the files each in different columns.
# These should be files without the full path.
#
# First, look at how many files there are for each sample / library:

# %%
(submissions_tidy
 .groupby(['biosample_accession', 'library_ID'])
 .aggregate(n_files=pd.NamedAgg('filename_fullpath', 'count'))
 .sort_values('n_files', ascending=False)
 .reset_index()
 )
# Out:
#    biosample_accession                        library_ID  n_files
# 0         SAMN30603977          lib12_exptREF-none-0-ref        4
# 1         SAMN30603977          lib13_exptREF-none-0-ref        4
# 2         SAMN30603977          lib22_exptREF-none-0-ref        4
# 3         SAMN30603977          lib23_exptREF-none-0-ref        4
# 4         SAMN30603977          lib24_exptREF-none-0-ref        4
# 5         SAMN30603977          lib25_exptREF-none-0-ref        2
# 6         SAMN30603977  lib12_expt1-LY-CoV1404-154-abneg        1
# 7         SAMN30603977  lib13_expt1-LY-CoV1404-154-abneg        1
# 8         SAMN30603977  lib22_expt25-LY-CoV1404-83-abneg        1
# 9         SAMN30603977  lib23_expt25-LY-CoV1404-83-abneg        1
# 10        SAMN30603977  lib24_expt9-LY-CoV1404-119-abneg        1
# 11        SAMN30603977  lib25_expt9-LY-CoV1404-119-abneg        1

# %% [markdown]
# Now make the wide submission data frame.
# Note we keep only the filename column with the path lacking the full directory information:

# %%
submissions_wide = (
    submissions_tidy
    .assign(
        filename_count=lambda x: x.groupby(['biosample_accession', 'library_ID'])['filename'].cumcount() + 1,
        filename_col=lambda x: 'filename' + x['filename_count'].map(lambda c: str(c) if c > 1 else '')
        )
    .pivot(
        index='library_ID',
        columns='filename_col',
        values='filename',
        )
    )

submissions_wide = (
    submissions_tidy
    .drop(columns=['filename_fullpath', 'filename'])
    .drop_duplicates()
    .merge(submissions_wide[natsort.natsorted(submissions_wide.columns)],
           on='library_ID',
           validate='one_to_one',
           )
    )

print('Here are the first few submission entries in wide format:')
submissions_wide.head()
# Out:
# Here are the first few submission entries in wide format:
#   biosample_accession                        library_ID  \
# 0        SAMN30603977          lib12_exptREF-none-0-ref
# 1        SAMN30603977          lib13_exptREF-none-0-ref
# 2        SAMN30603977  lib12_expt1-LY-CoV1404-154-abneg
# 3        SAMN30603977  lib13_expt1-LY-CoV1404-154-abneg
# 4        SAMN30603977          lib22_exptREF-none-0-ref
#
#                                                                                                           title  \
# 0   Illumina barcode sequencing from LY-CoV1404 mutational antigenic profiling of the SARS-CoV-2 RBD Wuhan_Hu_1
# 1   Illumina barcode sequencing from LY-CoV1404 mutational antigenic profiling of the SARS-CoV-2 RBD Wuhan_Hu_1
# 2   Illumina barcode sequencing from LY-CoV1404 mutational antigenic profiling of the SARS-CoV-2 RBD Wuhan_Hu_1
# 3   Illumina barcode sequencing from LY-CoV1404 mutational antigenic profiling of the SARS-CoV-2 RBD Wuhan_Hu_1
# 4  Illumina barcode sequencing from LY-CoV1404 mutational antigenic profiling of the SARS-CoV-2 RBD Omicron_BA1
#
#   library_strategy library_source library_selection library_layout  platform  \
# 0         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 1         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 2         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 3         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 4         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
#
#   instrument_model                 design_description filetype  \
# 0     NextSeq 2000  PCR of barcodes from RBD variants    fastq
# 1     NextSeq 2000  PCR of barcodes from RBD variants    fastq
# 2     NextSeq 2000  PCR of barcodes from RBD variants    fastq
# 3     NextSeq 2000  PCR of barcodes from RBD variants    fastq
# 4     NextSeq 2000  PCR of barcodes from RBD variants    fastq
#
#                             filename                          filename2  \
# 0  WH1_lib1_ref1_S33_R1_001.fastq.gz  WH1_lib1_ref2_S34_R1_001.fastq.gz
# 1  WH1_lib2_ref1_S37_R1_001.fastq.gz  WH1_lib2_ref2_S38_R1_001.fastq.gz
# 2      expt1_lib1_S1_R1_001.fastq.gz                                NaN
# 3      expt1_lib2_S2_R1_001.fastq.gz                                NaN
# 4  BA1_lib1_ref1_S54_R1_001.fastq.gz  BA1_lib1_ref2_S55_R1_001.fastq.gz
#
#                             filename3                          filename4
# 0  WH1_lib1_ref13_S35_R1_001.fastq.gz  WH1_lib1_ref4_S36_R1_001.fastq.gz
# 1   WH1_lib2_ref3_S39_R1_001.fastq.gz  WH1_lib2_ref4_S40_R1_001.fastq.gz
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4  BA1_lib1_ref13_S56_R1_001.fastq.gz  BA1_lib1_ref4_S57_R1_001.fastq.gz

# %% [markdown]
# Now write the wide submissions data frame to a `*.tsv` file that can be used for uploading the SRA submission website:

# %%
submissions_spreadsheet = 'SRA_submission_spreadsheet.tsv'

submissions_wide.to_csv(submissions_spreadsheet, sep='\t', index=False)

# %% [markdown]
# We also want to write a file with all of the FASTQ files that are in the submission spreadsheet:

# %%
fastq_file_list = 'FASTQs_to_upload.csv'

print(f"Writing list of all the FASTQ files to upload to {fastq_file_list}")

(submissions_tidy
 [['filename_fullpath', 'filename']]
 .to_csv(fastq_file_list, index=False)
 )
# Out:
# Writing list of all the FASTQ files to upload to FASTQs_to_upload.csv
